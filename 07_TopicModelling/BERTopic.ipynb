# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/NLP/blob/main/07_TopicModelling/BERTopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install  bertopic

# %%
from bertopic import BERTopic
from nltk.corpus import gutenberg 
import nltk 
from string import punctuation 
import numpy as np
import re

# %%
nltk.download('gutenberg')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
bible = gutenberg.sents("bible-kjv.txt")
remove_terms = punctuation + '0123456789'

# %%
stop_words = nltk.corpus.stopwords.words('english')

# %%
wpt = nltk.WordPunctTokenizer()

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc,re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)
     

norm_bible = [[word.lower() for word in sent if word not in remove_terms] for sent in bible]
norm_bible = [' '.join(tok_sent) for tok_sent in norm_bible]
norm_bible = filter(None, normalize_corpus(norm_bible))
norm_bible = [tok_sent for tok_sent in norm_bible if len(tok_sent.split()) > 2]
     

from keras.preprocessing import text
from keras.utils import np_utils
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(norm_bible)
word2id = tokenizer.word_index

# %%
norm_bible[100]
# Out:
# 'lord set mark upon cain lest finding kill'

# %%
len(norm_bible)
# Out:
# 29251

# %%
topic_model=BERTopic()

# %%
modelo=topic_model.fit_transform(norm_bible)

# %%
topic_model.get_topic_freq().head(11)
# Out:
#     Topic  Count
# 0      -1  12493
# 1       0    944
# 2       1    316
# 3       2    279
# 4       3    278
# 5       4    239
# 6       5    230
# 7       6    225
# 8       7    203
# 9       8    197
# 10      9    186

# %%
topic_model.get_topic(6)
# Out:
# [('judah', 0.05518296575003125),
#  ('jerusalem', 0.018536413009421195),
#  ('cities', 0.017295394362848212),
#  ('places', 0.009789957626803613),
#  ('stick', 0.008707533688494227),
#  ('captivity', 0.008413089963097297),
#  ('walls', 0.007349127653078259),
#  ('incense', 0.007052879557393603),
#  ('inhabitants', 0.006892074449431919),
#  ('ephraim', 0.006184070401469235)]

# %%
len(topic_model.get_topic_freq())
# Out:
# 338

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3658adbf-ba09-4f88-8208-fe2da204ae5b" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3658adbf-ba09-4f88-8208-fe2da204ae5b")) {                    Plotly.newPlot(                        "3658adbf-ba09-4f88-8208-fe2da204ae5b",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.014292644397183777,0.01607871906266611,0.017260188642933657,0.03399914850288849,0.04025934474607186],"y":["jonathan  ","solomon  ","samuel  ","saul  ","david  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.018302030872614852,0.018493075141283923,0.018726894276916192,0.018792085130271245,0.019650705801607462],"y":["art  ","say  ","answered  ","answer  ","said  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03746234107967143,0.037658409943993866,0.04015580641029661,0.0413595558972507,0.04627520919904158],"y":["cry  ","hear  ","voice  ","cried  ","ear  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.0073086772107301854,0.0074239124308075706,0.01050753354262748,0.012079825693546941,0.02324704922209091],"y":["house  ","word  ","saith  ","thus  ","israel  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.017620957954891433,0.018350415978580795,0.02256585954599737,0.03983244145727807,0.05090528340264796],"y":["deliver  ","thine  ","right  ","hands  ","hand  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.011524292849054272,0.016721931505091627,0.016802610034322037,0.025008736622881726,0.033275251811195845],"y":["houses  ","doors  ","build  ","door  ","house  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.008707533688494227,0.009789957626803613,0.017295394362848212,0.018536413009421195,0.05518296575003125],"y":["stick  ","places  ","cities  ","jerusalem  ","judah  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03233685433218178,0.035299123627474775,0.03913524522630191,0.04595587604941344,0.0468091885929535],"y":["fat  ","sacrifice  ","offering  ","burnt  ","offerings  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="006fd4cb-b825-4672-8a64-492dd8b2aaf8" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById