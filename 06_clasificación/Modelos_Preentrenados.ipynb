# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/NLP/blob/main/06_clasificaci%C3%B3n/Modelos_Preentrenados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("Wow, NLTK is really powerful!")
# Out:
# {'neg': 0.0, 'neu': 0.295, 'pos': 0.705, 'compound': 0.8012}

# %%
sia.polarity_scores("NLTK está buenísimo, qué feliz que soy")
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 60.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 95.4 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
sentiment_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
data = ["I love you", "I hate you", "Te amo", "Te odio", "Dame más!"]
sentiment_pipeline(data)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998656511306763},
#  {'label': 'NEGATIVE', 'score': 0.9991129040718079},
#  {'label': 'POSITIVE', 'score': 0.9861747026443481},
#  {'label': 'NEGATIVE', 'score': 0.9677633047103882},
#  {'label': 'POSITIVE', 'score': 0.9987732768058777}]

# %%
sentiment_pipeline("Messi es el puto amo")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.999319314956665}]

# %%
# Podemos especificar otro modelo preentrenado 
# https://huggingface.co/finiteautomata
specific_model = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# ...
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %%
specific_model(data)
# Out:
# [{'label': 'POS', 'score': 0.9916695356369019},
#  {'label': 'NEG', 'score': 0.9806600213050842},
#  {'label': 'POS', 'score': 0.8912532329559326},
#  {'label': 'NEU', 'score': 0.925968587398529},
#  {'label': 'NEU', 'score': 0.8672666549682617}]

# %%
specific_model("Messi es el puto amo")
# Out:
# [{'label': 'POS', 'score': 0.9394192695617676}]

# %%
specific_model_2 = pipeline(model="finiteautomata/bert-non-contextualized-hate-speech-es")
specific_model_2(data)
# Out:
# ...
# [{'label': 'Not hateful', 'score': 0.9994920492172241},
#  {'label': 'Not hateful', 'score': 0.9995198249816895},
#  {'label': 'Not hateful', 'score': 0.9993695616722107},
#  {'label': 'Not hateful', 'score': 0.9958409667015076},
#  {'label': 'Not hateful', 'score': 0.9995779395103455}]

# %%
data.append("Vamos a matarlos")

# %%
specific_model_2(data)
# Out:
# [{'label': 'Not hateful', 'score': 0.9994920492172241},
#  {'label': 'Not hateful', 'score': 0.9995198249816895},
#  {'label': 'Not hateful', 'score': 0.9993695616722107},
#  {'label': 'Not hateful', 'score': 0.9958409667015076},
#  {'label': 'Not hateful', 'score': 0.9995779395103455},
#  {'label': 'Hateful', 'score': 0.9707979559898376}]
