# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/AnalisisPredictivo/blob/master/08_NLP/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.seed(5)

from keras.layers import Input, Dense, SimpleRNN
from keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from keras import backend as K

# %%
df = pd.read_csv('https://raw.githubusercontent.com/LCaravaggio/AnalisisPredictivo/master/08_NLP/dinosaurios.txt', sep=" ", header=None)[0]
df.to_csv('/content/nombres_dinosaurios.txt')

# %%
import pandas as pd

# 1. LECTURA DEL SET DE DATOS
# ===========================================================
nombres = open('/content/nombres_dinosaurios.txt','r').read()
nombres = nombres.lower()

# Crear diccionario (listado de caracteres que no se repiten)
alfabeto = list(set(nombres))
tam_datos, tam_alfabeto = len(nombres), len(alfabeto)
print("En total hay %d caracteres, y el diccionario tiene un tamaño de %d caracteres." % (tam_datos, tam_alfabeto))

# Conversión de caracteres a índices y viceversa
car_a_ind = { car:ind for ind,car in enumerate(sorted(alfabeto))}
ind_a_car = { ind:car for ind,car in enumerate(sorted(alfabeto))}
#print(car_a_ind)
#print(ind_a_car)
# Out:
# En total hay 19909 caracteres, y el diccionario tiene un tamaño de 27 caracteres.

# %%
# 2. MODELO
# ===========================================================
n_a = 25    # Número de unidades en la capa oculta
entrada  = Input(shape=(None,tam_alfabeto))
a0 = Input(shape=(n_a,))

celda_recurrente = SimpleRNN(n_a, activation='tanh', return_state = True)
capa_salida = Dense(tam_alfabeto, activation='softmax')

salida = []
hs, _ = celda_recurrente(entrada, initial_state=a0)
salida.append(capa_salida(hs))
modelo = Model([entrada,a0],salida)
#modelo.summary()

opt = SGD(lr=0.0005)
modelo.compile(optimizer=opt, loss='categorical_crossentropy')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
# 3. EJEMPLOS DE ENTRENAMIENTO
# ===========================================================

# Crear lista con ejemplos de entrenamiento y mezclarla aleatoriamente
with open("/content/nombres_dinosaurios.txt") as f:
    ejemplos = f.readlines()
ejemplos = [x.lower().strip() for x in ejemplos]
np.random.shuffle(ejemplos)

# Crear ejemplos de entrenamiento usando un generador
def train_generator():
    while True:
        # Tomar un ejemplo aleatorio
        ejemplo = ejemplos[np.random.randint(0,len(ejemplos))]

        # Convertir el ejemplo a representación numérica
        X = [None] + [car_a_ind[c] for c in ejemplo]

        # Crear "Y", resultado de desplazar "X" un caracter a la derecha
        Y = X[1:] + [car_a_ind['\n']]

        # Representar "X" y "Y" en formato one-hot
        x = np.zeros((len(X),1,tam_alfabeto))
        onehot = to_categorical(X[1:],tam_alfabeto).reshape(len(X)-1,1,tam_alfabeto)
        x[1:,:,:] = onehot
        y = to_categorical(Y,tam_alfabeto).reshape(len(X),tam_alfabeto)

        # Activación inicial (matriz de ceros)
        a = np.zeros((len(X), n_a))

        yield [x, a], y

# %%
# 4. ENTRENAMIENTO
# ===========================================================
BATCH_SIZE = 80			# Número de ejemplos de entrenamiento a usar en cada iteración
NITS = 10000			# Número de iteraciones

for j in range(NITS):
    historia = modelo.fit_generator(train_generator(), steps_per_epoch=BATCH_SIZE, epochs=1, verbose=0)

    # Imprimir evolución del entrenamiento cada 1000 iteraciones
    if j%1000 == 0:
        print('\nIteración: %d, Error: %f' % (j, historia.history['loss'][0]) + '\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Iteración: 0, Error: 3.307387
#
#
# Iteración: 1000, Error: 2.418915
#
#
# Iteración: 2000, Error: 2.319694
#
#
# Iteración: 3000, Error: 2.320034
#
#
# Iteración: 4000, Error: 2.264831
#
#
# Iteración: 5000, Error: 2.194364
#
#
# Iteración: 6000, Error: 2.216943
#
#
# Iteración: 7000, Error: 2.262762
#
#
# Iteración: 8000, Error: 2.251400
#
#
# Iteración: 9000, Error: 2.181136

# %%
# 5. GENERACIÓN DE NOMBRES USANDO EL MODELO ENTRENADO
# ===========================================================
def generar_nombre(modelo,car_a_num,tam_alfabeto,n_a):
    # Inicializar x y a con ceros
    x = np.zeros((1,1,tam_alfabeto,))
    a = np.zeros((1, n_a))

    # Nombre generado y caracter de fin de linea
    nombre_generado = ''
    fin_linea = '\n'
    car = -1

    # Iterar sobre el modelo y generar predicción hasta tanto no se alcance
    # "fin_linea" o el nombre generado llegue a los 50 caracteres
    contador = 0
    while (car != fin_linea and contador != 50):
          # Generar predicción usando la celda RNN
          a, _ = celda_recurrente(K.constant(x), initial_state=K.constant(a))
          y = capa_salida(a)
          prediccion = K.eval(y)

          # Escoger aleatoriamente un elemento de la predicción (el elemento con
          # con probabilidad más alta tendrá más opciones de ser seleccionado)
          ix = np.random.choice(list(range(tam_alfabeto)),p=prediccion.ravel())

          # Convertir el elemento seleccionado a caracter y añadirlo al nombre generado
          car = ind_a_car[ix]
          nombre_generado += car

          # Crear x_(t+1) = y_t, y a_t = a_(t-1)
          x = to_categorical(ix,tam_alfabeto).reshape(1,1,tam_alfabeto)
          a = K.eval(a)

          # Actualizar contador y continuar
          contador += 1

          # Agregar fin de línea al nombre generado en caso de tener más de 50 caracteres
          if (contador == 50):
            nombre_generado += '\n'

    print(nombre_generado)

# %%
# Generar 100 ejemplos de nombres generados por el modelo ya entrenado
for i in range(100):
    generar_nombre(modelo,car_a_ind,tam_alfabeto,n_a)
# Out:
# kuauelajstrusisiodotinnoceeleapeupeanaururuos
#
# llonyus
#
# trtoseltaznaphosurniphusururuanechusvagauaurultrgy
#
# psaphaueoruameliavejilus
#
# a
#
# aloierurnolopsausephuss
#
# phapeerurbabeeeys
#
# urustiaunhaususerurururuileeruspomeleeiauenoruiuho
#
# rururxosaztoeonodeondagaeohuatodoxfanapoudprurustr
#
# micheiuruxiatopeus
#
#
#
# piauawodrururuontauphemurusischeusurur
#
#
#
# orosngchexpiaureu
#
# diopn
#
# s
#
# nusausharuaniceiaurveriururuhus
#
# phuriyvwes
#
# aperopracholulqryruruelozyguruhltauleeteedichesuru
#
# riaurjaeonfocrosuegorueeuophenamosareericeopaus
#
# onus
#
# tezxbaus
#
# tops
#
# eiazopopuepg
#
# sarorusphubtos
#
# morurumzaururthosazkhoceeoroeurus
#
# ocoplceieeruriaurururavurus
#
# penaroloasiodoslhururururtodibguitrusaowurusmidepe
#
# shururnopvaynurnis
#
# aeoboxis
#
# mimurupimapanopuelkaka
#
# ngosiryriztruruichaururus
#
# kusimdiceopruruereosocerorusurururus
#
# phas
#
# uimlsanychejhaushihururuesagotopepepengdlzu
#
# mius
#
# chaitrmexuenodtyjpiqdeloritrsaurus
#
# senonsururce
#
# phomurustottyveclonyrorus
#
# hinyurukustenyreuelornemorurus
#
# hcerofsarurueleururtiauimucuintyicuepnerourumurdon
#
# etogkrusleaheuriasanophucnovekaulkaxhesirusaschurl
#
# iceleruruhmoselopus
#
# us
#
# sis
#
# croprusphdctodurus
#
# ausas
#
# rururps
#
# tordapebiisurteibicvozeustruruvej
#
# piashaghocianonoomptmbleurus
#
# luxiaururmi
#
# lloleukururzhepeuacr
#
# fygbernochakojhmauauruoqus
#
# aualouryls
#
# olosuusantoltosaus
#
# tecerus
#
# trmodeaur
#
# tiana
#
# beledrururshemuraururtebauosuseionocopurucmavonsap
#
# abeuteemur
#
# tsachzgephyntelofnururgindoseverihsyurocapoqug
#
# aceanomosanoceipyphipthaphakoderorucehaznunde
#
# bingosinsuskodreusaaohozuapelocuuceuaseiprusaurusl
#
# ytehalomoedeanojeruruishosorusyleunpaullovlotenope
#
# llopsasapodoquruaurchegurce
#
# xceaus
#
# savusuruvmuptapstiaua
#
# ehianonodops
#
# ybusteipaegniesocphzeus
#
# viilurngyrurus
#
# aha
#
# skeeluspesarazhegenes
#
# ruatocahuluote
#
# onobndpsanlusisbeus
#
# inus
#
# iutsaundanurauelonteruelteicerururururur
#
# ciopeyanohus
#
# ydops
#
# ruouada
#
# ticeicodieonobloprururus
#
# theboptaus
#
# rorota
#
# miauhgaurus
#
# shus
#
# auruptogstrilpteiliaps
#
# iinyogovrucxaurus
#
# eebeptes
#
# s
#
# a
#
# s
#
# otogudecruauiiaus
#
# liagokoeururuaus
#
#
#
# aus
#
# phuicegosrqdus
#
# trygus
#
# fkauiqokugurimingmorustowlocheus
#
# ceeips
#
# uriameonurus
#
# eoururthysiauopsa
