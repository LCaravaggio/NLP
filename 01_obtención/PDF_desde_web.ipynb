# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/NLP/blob/main/01_obtenci%C3%B3n/PDF_desde_web.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests, PyPDF2
from io import BytesIO

url = 'https://www4.hcdn.gob.ar/dependencias/dip/Mensajes_Presidenciales/Mensaje%20Presidencial%202019.pdf'
response = requests.get(url)
my_raw_data = response.content

with BytesIO(my_raw_data) as data:
    read_pdf = PyPDF2.PdfReader(data)

    for page in range(len(read_pdf.pages)):
        print(read_pdf.pages[page].extract_text())
# Out:
# MENSAJE
# PRESIDENCIAL
# DR. ALBERTO ÁNGEL FERNÁNDEZ
# A LA HONORABLE ASAMBLEA LEGISLATIVA
# 10 DE DICIEMBRE DE 2019
# 2   PODER EJECUTIVO NACIONAL Presidente de la Nación D. Alberto Ángel Fernández Jefe de Gabinete de Ministros D. Santiago Andrés Cafiero Ministro de Agricultura, Ganadería y Pesca D. Luis Eugenio Basterra Ministro de Ambiente y Desarrollo Sostenible D. Juan Cabandié Ministro de Ciencia, Tecnología e Innovación D. Roberto Carlos Salvarezza Ministro de Cultura D. Tristán Bauer Ministro de Defensa D. Agustín Oscar Rossi Ministro de Desarrollo Productivo D. Matías Sebastián Kulfas Ministro de Desarrollo Social D. Daniel Fernando Arroyo Ministra de Desarrollo Territorial y Hábitat Da. María Eugenia Bielsa Ministro de Economía D. Martín Maximiliano Guzmán Ministro de Educación D. Nicolás Alfredo Trotta Ministro del Interior D. Eduardo Enrique De Pedro Ministra de Justicia y Derechos Humanos Da. Marcela Miriam Losardo
# ...
