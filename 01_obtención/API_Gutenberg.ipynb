# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/NLP/blob/main/01_obtenci%C3%B3n/API_Gutenberg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GutenbergPy
#
# https://github.com/raduangelescu/gutenbergpy

# %%
# !pip install gutenbergpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gutenbergpy
#   Downloading gutenbergpy-0.3.4-py3-none-any.whl (21 kB)
# Requirement already satisfied: lxml>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from gutenbergpy) (4.9.2)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (from gutenbergpy) (4.3.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.8/dist-packages (from gutenbergpy) (4.0.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.8/dist-packages (from gutenbergpy) (0.16.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from gutenbergpy) (57.4.0)
# Collecting httpsproxy-urllib2
#   Downloading httpsproxy_urllib2-1.0.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo->gutenbergpy) (2.3.0)
# Building wheels for collected packages: httpsproxy-urllib2
#   Building wheel for httpsproxy-urllib2 (setup.py) ... done
#   Created wheel for httpsproxy-urllib2: filename=httpsproxy_urllib2-1.0-py3-none-any.whl size=29268 sha256=92a83b89b22800e887dddb697932a06c383785e20d5022f1f276fc400278d527
#   Stored in directory: /root/.cache/pip/wheels/fd/12/70/68ccdc9a4afa13c9dabc90b32aede55c9f17d3395b56d0af23
# Successfully built httpsproxy-urllib2
# Installing collected packages: httpsproxy-urllib2, gutenbergpy
# Successfully installed gutenbergpy-0.3.4 httpsproxy-urllib2-1.0

# %%
import gutenbergpy.textget

text=gutenbergpy.textget.get_text_by_id(14765)
print(text)
# Out:
# b'The Project Gutenberg EBook of El Gaucho Mart\xc3\xadn Fierro, by Jos\xc3\xa9 Hern\xc3\xa1ndez\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.  You may copy it, give it away or\r\nre-use it under the terms of the Project Gutenberg License included\r\nwith this eBook or online at www.gutenberg.org\r\n\r\n\r\nTitle: El Gaucho Mart\xc3\xadn Fierro\r\n\r\nAuthor: Jos\xc3\xa9 Hern\xc3\xa1ndez\r\n\r\nRelease Date: January 23, 2005 [EBook #14765]\r\n\r\nLanguage: Spanish\r\n\r\nCharacter set encoding: ISO-8859-1\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK EL GAUCHO MARTIN FIERRO ***\r\n\r\n\r\n\r\n\r\nProduced by La Biblioteca Digital Argentina, formatted by Mariano\r\nCecowski Palacio.\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nEl Gaucho Mart\xc3\xadn Fierro\r\n\r\nde Jos\xc3\xa9 Hern\xc3\xa1ndez\r\n\r\n\r\nBuenos Aires,\r\nImprenta de La Pampa,\r\nVictoria 79.\r\n\r\n1872.\r\n\r\n\r\n\r\n\r\nCarta del Autor a don Jos\xc3\xa9 Zoilo Miguens\r\n\r\nQuerido amigo:\r\n\r\nAl fin me he decidido a que mi pobre "MART\xc3\x8dN FIERRO", que me ha ayudado\r\nalgunos momentos a alejar al fastidio de la vida del hotel, salga a\r\nconocer el mundo, y all\xc3\xa1 va acogido al amparo de su nombre.\r\n\r\nNo le niegue su protecci\xc3\xb3n, Ud. que conoce bien todos los abusos y\r\ntodas las desgracias de que es v\xc3\xadctima esa clase desheredada de nuestro\r\npa\xc3\xads. Es un pobre gaucho, con todas las imperfecciones de forma que el\r\narte tiene todav\xc3\xada entre ellos, y con toda la falta de enlace en sus\r\nideas, en las que no existe siempre una sucesi\xc3\xb3n l\xc3\xb3gica, descubri\xc3\xa9ndose\r\nfrecuentemente entre ellas apenas una relaci\xc3\xb3n oculta y remota.\r\n\r\nMe he esforzado, sin presumir haberlo conseguido, en presentar un tipo\r\nque personificara el car\xc3\xa1cter de nuestros gauchos, concentrando el modo\r\nde ser, de sentir, de pensar y de expresarse, que les es peculiar,\r\ndot\xc3\xa1ndolo con todos los juegos de su imaginaci\xc3\xb3n llena de im\xc3\xa1genes y de\r\ncolorido, con todos los arranques de su altivez, inmoderados hasta el\r\ncrimen, y con todos los impulsos y arrebatos, hijos de una naturaleza\r\nque la educaci\xc3\xb3n no ha pulido y suavizado.\r\n\r\nCuantos conozcan con propiedad el original podr\xc3\xa1n juzgar si hay o no\r\nsemejanza en la copia.\r\n\r\nQuiz\xc3\xa1 la empresa habr\xc3\xada sido para m\xc3\xad m\xc3\xa1s f\xc3\xa1cil, y de mejor \xc3\xa9xito, si\r\ns\xc3\xb3lo me hubiera propuesto hacer re\xc3\xadr a costa de su ignorancia, como se\r\nhalla autorizado por el uso en este g\xc3\xa9nero de composiciones; pero mi\r\nobjeto ha sido dibujar a grandes rasgos, aunque fielmente, sus\r\ncostumbres, sus trabajos, sus h\xc3\xa1bitos de vida, su \xc3\xadndole, sus vicios y\r\nsus virtudes; ese conjunto que constituye el cuadro de su fisonom\xc3\xada\r\nmoral, y los accidentes de su existencia llena de peligros, de\r\ninquietudes, de inseguridad, de aventuras y de agitaciones constantes.\r\n\r\nY he deseado todo esto, empe\xc3\xb1\xc3\xa1ndome en imitar ese estilo abundante en\r\nmet\xc3\xa1foras, que el gaucho usa sin conocer y sin valorar, y su empleo\r\nconstante de comparaciones tan extra\xc3\xb1as como frecuentes; en copiar sus\r\nreflexiones con el sello de la originalidad que las distingue y el\r\ntinte sombr\xc3\xado de que jam\xc3\xa1s carecen, revel\xc3\xa1ndose en ellas esa especie\r\nde filosof\xc3\xada propia que, sin estudiar, aprende en la misma naturaleza,\r\nen respetar la superstici\xc3\xb3n y sus preocupaciones, nacidas y fomentadas\r\npor su misma ignorancia; en dibujar el orden de sus impresiones y de\r\nsus afectos, que \xc3\xa9l encubre y disimula estudiosamente, sus desencantos,\r\nproducidos por su misma condici\xc3\xb3n social, y esa indolencia que le es\r\nhabitual, hasta llegar a constituir una de las condiciones de su\r\nesp\xc3\xadritu; en retratar, en fin, lo m\xc3\xa1s fielmente que me fuera posible, ...

# %%
gutenbergpy.textget.strip_headers(text)
# Out:
# b'Cecowski Palacio.\n\n\n\n\n\n\n\nEl Gaucho Mart\xc3\xadn Fierro\n\nde Jos\xc3\xa9 Hern\xc3\xa1ndez\n\n\nBuenos Aires,\nImprenta de La Pampa,\nVictoria 79.\n\n1872.\n\n\n\n\nCarta del Autor a don Jos\xc3\xa9 Zoilo Miguens\n\nQuerido amigo:\n\nAl fin me he decidido a que mi pobre "MART\xc3\x8dN FIERRO", que me ha ayudado\nalgunos momentos a alejar al fastidio de la vida del hotel, salga a\nconocer el mundo, y all\xc3\xa1 va acogido al amparo de su nombre.\n\nNo le niegue su protecci\xc3\xb3n, Ud. que conoce bien todos los abusos y\ntodas las desgracias de que es v\xc3\xadctima esa clase desheredada de nuestro\npa\xc3\xads. Es un pobre gaucho, con todas las imperfecciones de forma que el\narte tiene todav\xc3